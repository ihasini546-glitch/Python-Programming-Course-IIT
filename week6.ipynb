# %% [markdown]
# <a href="https://colab.research.google.com/github/ihasini546-glitch/Python-Programming-Course-IIT/blob/main/week6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
list_1=[]
print(type(list_1))
print(list_1)
# Out:
# <class 'list'>
# []

# %%
list_2=list()
print(type(list_2))
print(list_2)
# Out:
# <class 'list'>
# []

# %%
mylist3=[1,2,3,4,5]
mylist4=list((7,8,9,10))
print(mylist3)
print(mylist4)
# Out:
# [1, 2, 3, 4, 5]
# [7, 8, 9, 10]

# %%
fruits=["apple","banana","apple","cherry","banana"]
print(fruits)
# Out:
# ['apple', 'banana', 'apple', 'cherry', 'banana']

# %%
numbers=[10,20,30,40]
print(numbers)
numbers.append(90)
print(numbers)
# Out:
# [10, 20, 30, 40]
# [10, 20, 30, 40, 90]

# %%
fruits_2=["banana","mango","papaya"]
print(fruits_2)
fruits_2[1]="orange"
print(fruits_2)
# Out:
# ['banana', 'mango', 'papaya']
# ['banana', 'orange', 'papaya']

# %%
fruits_3=["orange","baanna"]
print(fruits_3)
fruits_3.insert(1,"cherry")
print(fruits_3)
# Out:
# ['orange', 'baanna']
# ['orange', 'cherry', 'baanna']

# %%
my_list=[20,"daou",34,57,57,False,"offroad"]
print(my_list[0])
print(my_list[:2])
print(my_list[::-1])
print(len(my_list))
print(my_list.index(34))
print(my_list[2:5])
print(my_list.count(57))
print(my_list.reverse())
# Out:
# 20
# [20, 'daou']
# ['offroad', False, 57, 57, 34, 'daou', 20]
# 7
# 2
# [34, 57, 57]
# 2
# None

# %%
numbers_01=[5,10,15,20]
print(numbers_01)
print(numbers_01[1])
# Out:
# [5, 10, 15, 20]
# 10

# %%
print(numbers_01[-1])
# Out:
# 20

# %%
nums=[2,4,6,8,10]
print(nums[1:4])
# Out:
# [4, 6, 8]

# %%
my_tuple=(1,2,2,30,4,5)
print(my_tuple)
print(my_tuple.count(2))
print(my_tuple.index(30))
# Out:
# (1, 2, 2, 30, 4, 5)
# 2
# 3

# %%
def greet():
  print("hello world")

# %%
greet()
# Out:
# hello world

# %%
def greet(name):
  print(f"hello,{name}!")

# %%
greet("hasini")
# Out:
# hello,hasini!
