# %% [markdown]
# <a href="https://colab.research.google.com/github/ihasini546-glitch/Python-Programming-Course-IIT/blob/main/week8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
str_name="hasini"+"_"+"iranga"
print(str_name)
# Out:
# hasini_iranga

# %%
import numpy

# %%
import pandas

# %%
student1={"name":"hasini","grade":"A"}
print(student1["name"])
student1["name"]
# Out:
# hasini
# 'hasini'

# %%
x=[5]
x.append(10)
print(x)
# Out:
# [5, 10]

# %%
y=10
try:
  print(y)
except:
  print("An exception occured")
# Out:
# 10
