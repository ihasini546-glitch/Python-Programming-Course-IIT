# %%
x=open(r"C:\Users\Public\CyberLink\python_content.txt","r")
print(x.name)
print("closed",x.closed)
x.close()
print("closed",x.closed)
# Out:
# C:\Users\Public\CyberLink\python_content.txt
# closed False
# closed True

# %%
x=open(r"C:\Users\Public\CyberLink\python_content.txt","r")
print(x.read())
# Out:
# djgjusgfissbvksbvsbcjxbvjcjhcd
# fuigeeisgfbc djvbdbv dj
# bdjgjusgfissbvksbvsbcjxbvjcjhcd
# fuigeeisgfbc djvbdbv dj
# bdjgjusgfissbvksbvsbcjxbvjcjhcd
# fuigeeisgfbc djvbdbv dj
# bjdjgjusgfissbvksbvsbcjxbvjcjhcd
# fuigeeisgfbc djvbdbv dj
# bdjgjusgfissbvksbvsbcjxbvjcjhcd
# fuigeeisgfbc djvbdbv dj
# bjbv djihfurfuifgjbv djihfurfuifgbv djihfurfuifgjbv djihfurfuifgjbv djihfurfuifg

# %%
x=open(r"C:\Users\Public\CyberLink\python_content.txt","r")
print(x.readlines())
# Out:
# ['djgjusgfissbvksbvsbcjxbvjcjhcd\n', 'fuigeeisgfbc djvbdbv dj\n', 'bdjgjusgfissbvksbvsbcjxbvjcjhcd\n', 'fuigeeisgfbc djvbdbv dj\n', 'bdjgjusgfissbvksbvsbcjxbvjcjhcd\n', 'fuigeeisgfbc djvbdbv dj\n', 'bjdjgjusgfissbvksbvsbcjxbvjcjhcd\n', 'fuigeeisgfbc djvbdbv dj\n', 'bdjgjusgfissbvksbvsbcjxbvjcjhcd\n', 'fuigeeisgfbc djvbdbv dj\n', 'bjbv djihfurfuifgjbv djihfurfuifgbv djihfurfuifgjbv djihfurfuifgjbv djihfurfuifg']

# %%
with open(r"C:\Users\Public\CyberLink\python_content.txt","r") as x:
    print(x.name)
# Out:
# C:\Users\Public\CyberLink\python_content.txt

# %%
x=open(r"C:\Users\Public\CyberLink\python_content.txt")
for line in x:
    print(line.strip())
x.close()
# Out:
# djgjusgfissbvksbvsbcjxbvjcjhcd
# fuigeeisgfbc djvbdbv dj
# bdjgjusgfissbvksbvsbcjxbvjcjhcd
# fuigeeisgfbc djvbdbv dj
# bdjgjusgfissbvksbvsbcjxbvjcjhcd
# fuigeeisgfbc djvbdbv dj
# bjdjgjusgfissbvksbvsbcjxbvjcjhcd
# fuigeeisgfbc djvbdbv dj
# bdjgjusgfissbvksbvsbcjxbvjcjhcd
# fuigeeisgfbc djvbdbv dj
# bjbv djihfurfuifgjbv djihfurfuifgbv djihfurfuifgjbv djihfurfuifgjbv djihfurfuifg

# %%
x=open(r"C:\Users\Public\CyberLink\python_content.txt","r")
for line in x:
    print(line)
# Out:
# djgjusgfissbvksbvsbcjxbvjcjhcd
#
# fuigeeisgfbc djvbdbv dj
#
# bdjgjusgfissbvksbvsbcjxbvjcjhcd
#
# fuigeeisgfbc djvbdbv dj
#
# bdjgjusgfissbvksbvsbcjxbvjcjhcd
#
# fuigeeisgfbc djvbdbv dj
#
# bjdjgjusgfissbvksbvsbcjxbvjcjhcd
#
# fuigeeisgfbc djvbdbv dj
#
# bdjgjusgfissbvksbvsbcjxbvjcjhcd
#
# fuigeeisgfbc djvbdbv dj
#
# bjbv djihfurfuifgjbv djihfurfuifgbv djihfurfuifgjbv djihfurfuifgjbv djihfurfuifg

# %%
x=open(r"C:\Users\Public\CyberLink\python_content.txt")
for line in x:
    if line.startswith("offroad"):
        print(line)
# Out:
# offroad dgywivxivcwwciss

# %%
target="daou"
x=open(r"C:\Users\Public\CyberLink\python_content.txt")
for line in x:
    if target in line:
        print(line)
# Out:
# bdjgjusgfiss daou bvksbvsbcjxbvjcjhcd

# %%
x=open(r"C:\Users\Public\CyberLink\python_content.txt","w")
x.write("python is fun 1\n")
x.write("python is fun 2\n")
x.close()

# %%
x=open(r"C:\Users\Public\CyberLink\python_content.txt","r")
print(x.read())
x.close()
# Out:
# python is fun 1python is fun 2

# %%
x = open(r"C:\Users\Public\CyberLink\python_content.txt", "a")
x.write("python is fun\n")
x.close()

# %%
x=open(r"C:\Users\Public\CyberLink\python_content.txt","a")
print(x.mode)
x.close()()
# Out:
# a
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 3
#       1 x=open(r"C:\Users\Public\CyberLink\python_content.txt","a")
#       2 print(x.mode)
# ----> 3 x.close()()
#
# TypeError: 'NoneType' object is not callable
